# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Method-I:-For-Loop" data-toc-modified-id="Method-I:-For-Loop-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Method I: For Loop</a></span></li><li><span><a href="#Method-II:-List-Comprehension" data-toc-modified-id="Method-II:-List-Comprehension-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Method II: List Comprehension</a></span></li><li><span><a href="#Method-III:-Combining" data-toc-modified-id="Method-III:-Combining-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Method III: Combining</a></span></li></ul></div>

# %%
import numpy as np
import os
import random
import matplotlib.pyplot  as plt

# %%
arr=[1,2,3,4,5,6,6,7,7,7,7,8,5,3,2]
np_arr=np.array(arr)

# %%
np_arr
# Out:
# array([1, 2, 3, 4, 5, 6, 6, 7, 7, 7, 7, 8, 5, 3, 2])

# %% [markdown]
# Note: () for functions, [] for calling elements of a list or array.

# %%
def my_function(x):
    return x**2

# %%
my_function(10)
# Out:
# 100

# %% [markdown]
# # Method I: For Loop

# %%
arr1=[]
for i in range(100):
    arr1.append(i**(1/2)+1+i**1.2)

# %% [markdown]
# plt.plot(Xvalues,Yvalues,....properties)
#
# plt.show()

# %%
plt.plot(range(100),arr1)
plt.show()

# %%
arr2=[]
for i in range(1000):
    arr2.append(random.random())

# %%
plt.plot(range(1000),arr2)
plt.show()

# %% [markdown]
# # Method II: List Comprehension

# %%
arr3=[i**(1/2) for i in range(100)]

# %%
plt.plot(range(100),arr3)

# %%
arr4=[random.random() for i in range(100)]

# %%
arr4
# Out:
# [0.4677470120193655,
#  0.3317484141058775,
#  0.1554809847545947,
#  0.046428194156239666,
#  0.9795077521460224,
#  0.456087800608336,
#  0.7114078682570558,
#  0.10564301441268553,
#  0.9973404989231213,
#  0.30745393223889017,
#  0.9364102451782198,
#  0.14810927753109027,
#  0.1308547450112807,
#  0.8098033563587368,
#  0.2887557272188972,
#  0.7094562124553252,
#  0.27378247975728387,
#  0.8145629435466651,
#  0.7121008820849284,
#  0.7756102503834097,
#  0.665844995291566,
#  0.5476473067513714,
#  0.5944933866840114,
#  0.6772270493636959,
#  0.905121195111777,
#  0.9916078714871498,
#  0.20773776814764144,
#  0.06997068466432077,
#  0.3563918023384056,
#  0.8676208397330447,
#  0.5079396725600689,
#  0.4310852520817984,
#  0.4887512063784968,
#  0.5608152787264591,
#  0.44978978793851276,
#  0.6675865559210444,
#  0.6503156442733342,
#  0.15885964812080733,
#  0.9373016529471495,
#  0.28120053113472454,
#  0.9462242886996004,
#  0.9507744024771204,
#  0.8860799999362302,
# ...

# %% [markdown]
# # Method III: Combining

# %%
len(arr3+arr4), len(arr3),len(arr4)
# Out:
# (200, 100, 100)
